# %%
from tweedledum.classical import create_from_binary_string, TruthTable

tt = TruthTable(3)
create_from_binary_string(tt, "11001110")
print(tt)
# Out:
# 11001110

# %%
from tweedledum.synthesis import pprm_synth

circuit = pprm_synth(tt)
print(circuit)
# Out:
#        ╭───╮╭───╮╭───╮╭───╮╭───╮
# __q3 : ┤ x ├┤ x ├┤ x ├┤ x ├┤ x ├
#        ╰─┬─╯╰─┬─╯╰─┬─╯╰─┬─╯╰─┬─╯
# __q2 : ──┼────┼────┼────●────●──
#          │    │    │    │    │
# __q1 : ──┼────●────●────┼────●──
#          │         │    │    │
# __q0 : ──●─────────●────●────●──
